# %% [markdown]
# # DataFrames I

# %%
import pandas as pd

# %% [markdown]
# ## Methods and Attributes between Series and DataFrames
# - A **DataFrame** is a 2-dimensional table consisting of rows and columns.
# - Pandas uses a `NaN` designation for cells that have a missing value. It is short for "not a number". Most operations on `NaN` values will produce `NaN` values.
# - Like with a **Series**, Pandas assigns an index position/label to each **DataFrame** row.
# - The **DataFrame** and **Series** have common and exclusive methods/attributes.
# - The `hasnans` attribute exists only a **Series**. The `columns` attribute exists only on a **DataFrame**.
# - Some methods/attributes will return different types of data.
# - The `info` method returns a summary of the pandas object.

# %%
nba = pd.read_csv('nba.csv')
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
# 591                NaN                 NaN      NaN    NaN     NaN
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# ...

# %%
nba.head(n=5)
nba.head(9)

nba.tail()
nba.tail(1)

nba.tail(7)
# Out:
#                  Name                Team Position Height  Weight  \
# 585    Eugene Omoruyi  Washington Wizards        F    6-6   235.0
# 586      Jordan Poole  Washington Wizards        G    6-4   194.0
# 587      Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588     Landry Shamet  Washington Wizards        G    6-4   190.0
# 589  Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590      Delon Wright  Washington Wizards        G    6-5   185.0
# 591               NaN                 NaN      NaN    NaN     NaN
#
#            College      Salary
# 585         Oregon    559782.0
# 586       Michigan  27955357.0
# 587         Toledo   1719864.0
# 588  Wichita State  10250000.0
# 589    Real Madrid         NaN
# 590           Utah   8195122.0
# 591            NaN         NaN

# %%
nba.index
# Out:
# RangeIndex(start=0, stop=592, step=1)

# %%
nba.values
# Out:
# array([['Saddiq Bey', 'Atlanta Hawks', 'F', ..., 215.0, 'Villanova',
#         4556983.0],
#        ['Bogdan Bogdanovic', 'Atlanta Hawks', 'G', ..., 225.0,
#         'Fenerbahce', 18700000.0],
#        ['Kobe Bufkin', 'Atlanta Hawks', 'G', ..., 195.0, 'Michigan',
#         4094244.0],
#        ...,
#        ['Tristan Vukcevic', 'Washington Wizards', 'F', ..., 220.0,
#         'Real Madrid', nan],
#        ['Delon Wright', 'Washington Wizards', 'G', ..., 185.0, 'Utah',
#         8195122.0],
#        [nan, nan, nan, ..., nan, nan, nan]], dtype=object)

# %%
nba.shape  #rows , columns
# Out:
# (592, 7)

# %%
nba.dtypes  #in data frames  , multiple columns where each column can have different datatype
# Out:
# Name         object
# Team         object
# Position     object
# Height       object
# Weight      float64
# College      object
# Salary      float64
# dtype: object

# %%
# nba.hasnans  #this attribute do not exist in dataframes , exist in Series

# %%
nba.columns #this attribute exist only in dataframes , not in Series
# Out:
# Index(['Name', 'Team', 'Position', 'Height', 'Weight', 'College', 'Salary'], dtype='object')

# %%
nba.axes
# Out:
# [RangeIndex(start=0, stop=592, step=1),
#  Index(['Name', 'Team', 'Position', 'Height', 'Weight', 'College', 'Salary'], dtype='object')]

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 592 entries, 0 to 591
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      591 non-null    object
#  1   Team      591 non-null    object
#  2   Position  584 non-null    object
#  3   Height    585 non-null    object
#  4   Weight    584 non-null    float64
#  5   College   578 non-null    object
#  6   Salary    488 non-null    float64
# dtypes: float64(2), object(5)
# memory usage: 32.5+ KB

# %% [markdown]
# ## Differences between Shared Methods
# - The `sum` method adds a **Series's** values.
# - On a **DataFrame**, the `sum` method defaults to adding the values by traversing the index (row values).
# - The `axis` parameter customizes the direction that we add across. Pass `"columns"` or `1` to add "across" the columns.

# %%
pd.read_csv('revenue.csv')
# Out:
#       Date  New York  Los Angeles  Miami
# 0   1/1/26       985          122    499
# 1   1/2/26       738          788    534
# 2   1/3/26        14           20    933
# 3   1/4/26       730          904    885
# 4   1/5/26       114           71    253
# 5   1/6/26       936          502    497
# 6   1/7/26       123          996    115
# 7   1/8/26       935          492    886
# 8   1/9/26       846          954    823
# 9  1/10/26        54          285    216

# %%
revenue = pd.read_csv('revenue.csv' ,index_col=['Date'])
revenue
# Out:
#          New York  Los Angeles  Miami
# Date
# 1/1/26        985          122    499
# 1/2/26        738          788    534
# 1/3/26         14           20    933
# 1/4/26        730          904    885
# 1/5/26        114           71    253
# 1/6/26        936          502    497
# 1/7/26        123          996    115
# 1/8/26        935          492    886
# 1/9/26        846          954    823
# 1/10/26        54          285    216

# %%
s = pd.Series([1,2,3])
sum(s) #or 
s.sum()
# Out:
# 6

# %%
revenue.sum()
# Out:
# New York       5475
# Los Angeles    5134
# Miami          5641
# dtype: int64

# %%
revenue.sum(axis= 'index')  #calculates the entire values of each column
# Out:
# New York       5475
# Los Angeles    5134
# Miami          5641
# dtype: int64

# %%
revenue.sum(axis='columns')  #gives the calculated value ,calculating row wise or  for each date total sales from 3 columns for specific date
# Out:
# Date
# 1/1/26     1606
# 1/2/26     2060
# 1/3/26      967
# 1/4/26     2519
# 1/5/26      438
# 1/6/26     1935
# 1/7/26     1234
# 1/8/26     2313
# 1/9/26     2623
# 1/10/26     555
# dtype: int64

# %%
revenue.sum(axis='columns').sum() #thats the total sum of everything in the dataframe
# Out:
# 16250

# %% [markdown]
# ## Select One Column from a DataFrame
# - We can use attribute syntax (`df.column_name`) to select a column from a **DataFrame**. The syntax will not work if the column name has spaces.
# - We can also use square bracket syntax (`df["column name"]`) which will work for any column name.
# - Pandas extracts a column from a **DataFrame** as a **Series**.
# - The **Series** is a view, so changes to the **Series** *will* affect the **DataFrame**.
# - Pandas will display a warning if you mutate the **Series**. Use the `copy` method to create a duplicate.

# %%
nba = pd.read_csv('nba.csv')
nba.head()
# Out:
#                 Name           Team Position Height  Weight      College  \
# 0         Saddiq Bey  Atlanta Hawks        F    6-7   215.0    Villanova
# 1  Bogdan Bogdanovic  Atlanta Hawks        G    6-5   225.0   Fenerbahce
# 2        Kobe Bufkin  Atlanta Hawks        G    6-5   195.0     Michigan
# 3       Clint Capela  Atlanta Hawks        C   6-10   256.0  Elan Chalon
# 4     Bruno Fernando  Atlanta Hawks      F-C   6-10   240.0     Maryland
#
#        Salary
# 0   4556983.0
# 1  18700000.0
# 2   4094244.0
# 3  20616000.0
# 4   2581522.0

# %%
nba.Team   #can use both, will give same result , but this one will not work if column name will have spaces in between
nba['Team']  # but this will work for all
# Out:
# 0           Atlanta Hawks
# 1           Atlanta Hawks
# 2           Atlanta Hawks
# 3           Atlanta Hawks
# 4           Atlanta Hawks
#               ...
# 587    Washington Wizards
# 588    Washington Wizards
# 589    Washington Wizards
# 590    Washington Wizards
# 591                   NaN
# Name: Team, Length: 592, dtype: object

# %%
nba.Salary.head()
nba.Weight
nba.Height
#nba.height will give error , it is case sensitive
# Out:
# 0       6-7
# 1       6-5
# 2       6-5
# 3      6-10
# 4      6-10
#        ...
# 587     6-3
# 588     6-4
# 589    6-10
# 590     6-5
# 591     NaN
# Name: Height, Length: 592, dtype: object

# %%
type(nba.Height)
# Out:
# pandas.core.series.Series

# %%
nba['Team']  #this synta, using square brackkets is more preferable
nba['Position']
# Out:
# 0        F
# 1        G
# 2        G
# 3        C
# 4      F-C
#       ...
# 587      G
# 588      G
# 589      F
# 590      G
# 591    NaN
# Name: Position, Length: 592, dtype: object

# %%
names = nba['Name'].copy()  #this is to make copy of original data source , so that any changes made will not affect the original data source 
names                       # but changes will made in copy
# Out:
# 0             Saddiq Bey
# 1      Bogdan Bogdanovic
# 2            Kobe Bufkin
# 3           Clint Capela
# 4         Bruno Fernando
#              ...
# 587         Ryan Rollins
# 588        Landry Shamet
# 589     Tristan Vukcevic
# 590         Delon Wright
# 591                  NaN
# Name: Name, Length: 592, dtype: object

# %%
names.iloc[0]
# Out:
# 'Saddiq Bey'

# %%
names.iloc[0] = 'Whatever'

# %%
names.head()
# Out:
# 0             Whatever
# 1    Bogdan Bogdanovic
# 2          Kobe Bufkin
# 3         Clint Capela
# 4       Bruno Fernando
# Name: Name, dtype: object

# %%
nba.head()
# Out:
#                 Name           Team Position Height  Weight      College  \
# 0         Saddiq Bey  Atlanta Hawks        F    6-7   215.0    Villanova
# 1  Bogdan Bogdanovic  Atlanta Hawks        G    6-5   225.0   Fenerbahce
# 2        Kobe Bufkin  Atlanta Hawks        G    6-5   195.0     Michigan
# 3       Clint Capela  Atlanta Hawks        C   6-10   256.0  Elan Chalon
# 4     Bruno Fernando  Atlanta Hawks      F-C   6-10   240.0     Maryland
#
#        Salary
# 0   4556983.0
# 1  18700000.0
# 2   4094244.0
# 3  20616000.0
# 4   2581522.0

# %% [markdown]
# ## Select Multiple Columns from a DataFrame
# - Use square brackets with a list of names to extract multiple **DataFrame** columns.
# - Pandas stores the result in a new **DataFrame** (a copy).

# %%
nba = pd.read_csv('nba.csv')
nba.head()
# Out:
#                 Name           Team Position Height  Weight      College  \
# 0         Saddiq Bey  Atlanta Hawks        F    6-7   215.0    Villanova
# 1  Bogdan Bogdanovic  Atlanta Hawks        G    6-5   225.0   Fenerbahce
# 2        Kobe Bufkin  Atlanta Hawks        G    6-5   195.0     Michigan
# 3       Clint Capela  Atlanta Hawks        C   6-10   256.0  Elan Chalon
# 4     Bruno Fernando  Atlanta Hawks      F-C   6-10   240.0     Maryland
#
#        Salary
# 0   4556983.0
# 1  18700000.0
# 2   4094244.0
# 3  20616000.0
# 4   2581522.0

# %%
#to extract multiple columns ,use double square brackets
nba[['Name','Team']]
nba[['Team','Name']]

nba[['Salary','Height','College']]
# Out:
#          Salary Height        College
# 0     4556983.0    6-7      Villanova
# 1    18700000.0    6-5     Fenerbahce
# 2     4094244.0    6-5       Michigan
# 3    20616000.0   6-10    Elan Chalon
# 4     2581522.0   6-10       Maryland
# ..          ...    ...            ...
# 587   1719864.0    6-3         Toledo
# 588  10250000.0    6-4  Wichita State
# 589         NaN   6-10    Real Madrid
# 590   8195122.0    6-5           Utah
# 591         NaN    NaN            NaN
#
# [592 rows x 3 columns]

# %%
columns_to_select = ['Salary','Height','College']
nba[columns_to_select]
# Out:
#          Salary Height        College
# 0     4556983.0    6-7      Villanova
# 1    18700000.0    6-5     Fenerbahce
# 2     4094244.0    6-5       Michigan
# 3    20616000.0   6-10    Elan Chalon
# 4     2581522.0   6-10       Maryland
# ..          ...    ...            ...
# 587   1719864.0    6-3         Toledo
# 588  10250000.0    6-4  Wichita State
# 589         NaN   6-10    Real Madrid
# 590   8195122.0    6-5           Utah
# 591         NaN    NaN            NaN
#
# [592 rows x 3 columns]

# %% [markdown]
# ## Add New Column to DataFrame
# - Use square bracket extraction syntax with an equal sign to add a new **Series** to a **DataFrame**.
# - The `insert` method allows us to insert an element at a specific column index.
# - On the right-hand side, we can reference an existing **DataFrame** column and perform a broadcasting operation on it to create the new **Series**.

# %%
nba = pd.read_csv('nba.csv')
nba.head()
# Out:
#                 Name           Team Position Height  Weight      College  \
# 0         Saddiq Bey  Atlanta Hawks        F    6-7   215.0    Villanova
# 1  Bogdan Bogdanovic  Atlanta Hawks        G    6-5   225.0   Fenerbahce
# 2        Kobe Bufkin  Atlanta Hawks        G    6-5   195.0     Michigan
# 3       Clint Capela  Atlanta Hawks        C   6-10   256.0  Elan Chalon
# 4     Bruno Fernando  Atlanta Hawks      F-C   6-10   240.0     Maryland
#
#        Salary
# 0   4556983.0
# 1  18700000.0
# 2   4094244.0
# 3  20616000.0
# 4   2581522.0

# %%
nba['Sport'] = 'Basketball'
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
# 591                NaN                 NaN      NaN    NaN     NaN
#
#            College      Salary       Sport
# 0        Villanova   4556983.0  Basketball
# 1       Fenerbahce  18700000.0  Basketball
# ...

# %%
nba.insert(loc=7,column='Sport' , value ='Basketball')

# %%
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
# 591                NaN                 NaN      NaN    NaN     NaN
#
#            College      Salary       Sport
# 0        Villanova   4556983.0  Basketball
# 1       Fenerbahce  18700000.0  Basketball
# ...

# %%
nba['Salary Double'] = nba['Salary'] * 2
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
# 591                NaN                 NaN      NaN    NaN     NaN
#
#            College      Salary  Salary Double
# 0        Villanova   4556983.0      9113966.0
# 1       Fenerbahce  18700000.0     37400000.0
# ...

# %%
nba["New Salary"] = nba['Salary'] -5000000
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
# 591                NaN                 NaN      NaN    NaN     NaN
#
#            College      Salary  Salary Double  New Salary
# 0        Villanova   4556983.0      9113966.0   -443017.0
# ...

# %% [markdown]
# ## A Review of the value_counts Method
# - The `value_counts` method counts the number of times that each unique value occurs in a **Series**.

# %%
nba = pd.read_csv('nba.csv')
nba.head()
# Out:
#                 Name           Team Position Height  Weight      College  \
# 0         Saddiq Bey  Atlanta Hawks        F    6-7   215.0    Villanova
# 1  Bogdan Bogdanovic  Atlanta Hawks        G    6-5   225.0   Fenerbahce
# 2        Kobe Bufkin  Atlanta Hawks        G    6-5   195.0     Michigan
# 3       Clint Capela  Atlanta Hawks        C   6-10   256.0  Elan Chalon
# 4     Bruno Fernando  Atlanta Hawks      F-C   6-10   240.0     Maryland
#
#        Salary
# 0   4556983.0
# 1  18700000.0
# 2   4094244.0
# 3  20616000.0
# 4   2581522.0

# %%
nba['Team'].value_counts()

nba['Team'].value_counts().head()
# Out:
# Team
# Dallas Mavericks     23
# Miami Heat           22
# Denver Nuggets       22
# Milwaukee Bucks      22
# Memphis Grizzlies    22
# Name: count, dtype: int64

# %%
nba['Position'].value_counts()

nba['Position'].value_counts(normalize=True)  #this gives relastive perc of occurance
nba['Position'].value_counts(normalize=True) * 100
# Out:
# Position
# G      39.212329
# F      32.020548
# C       8.047945
# G-F     7.876712
# F-C     6.335616
# C-F     3.938356
# F-G     2.568493
# Name: proportion, dtype: float64

# %%
nba['Position'].value_counts(normalize = False)  #this do not give the perc, as it iis false , gives the exact number of occurance
# Out:
# Position
# G      229
# F      187
# C       47
# G-F     46
# F-C     37
# C-F     23
# F-G     15
# Name: count, dtype: int64

# %%
nba['Salary'].value_counts()
# Out:
# Salary
# 559782.0      59
# 1119563.0     27
# 3196448.0     13
# 2019706.0      9
# 1719864.0      8
#               ..
# 9600000.0      1
# 3536280.0      1
# 8809284.0      1
# 40806300.0     1
# 8195122.0      1
# Name: count, Length: 298, dtype: int64

# %% [markdown]
# ## Drop Rows with Missing Values
# - Pandas uses a `NaN` designation for cells that have a missing value.
# - The `dropna` method deletes rows with missing values. Its default behavior is to remove a row if it has *any* missing values.
# - Pass the `how` parameter an argument of "all" to delete rows where all the values are `NaN`.
# - The `subset` parameters customizes/limits the columns that pandas will use to drop rows with missing values.

# %%
nba = pd.read_csv('nba.csv')
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
# 591                NaN                 NaN      NaN    NaN     NaN
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# ...

# %%
nba.dropna()  #by defualt it will remove any row , if it has a even a single missing value  , both are same syntax
nba.dropna(how='any')   #removes any row that has even a single missing value
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 585     Eugene Omoruyi  Washington Wizards        F    6-6   235.0
# 586       Jordan Poole  Washington Wizards        G    6-4   194.0
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# ...

# %%
nba.dropna(how='all')  #removes any row which has missing values , means the row which has missings value in each column , if theres a single value present 
                        # it will not remove that row
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 586       Jordan Poole  Washington Wizards        G    6-4   194.0
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# ...

# %%
nba.dropna(subset=['Salary'])  #with subset we can work with a column, if there is a missing a value in that column, it will remove that row
nba.dropna(subset=['Salary' ,'College']) #we can also add two columns, if either or both of them has any missing values , that row will be removed
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 585     Eugene Omoruyi  Washington Wizards        F    6-6   235.0
# 586       Jordan Poole  Washington Wizards        G    6-4   194.0
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# ...

# %% [markdown]
# ## Fill in Missing Values with the fillna Method
# - The `fillna` method replaces missing `NaN` values with its argument.
# - The `fillna` method is available on both **DataFrames** and **Series**.
# - An extracted **Series** is a view on the original **DataFrame**, but the `fillna` method returns a copy.

# %%
nba = pd.read_csv('nba.csv').dropna(how='all')
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 586       Jordan Poole  Washington Wizards        G    6-4   194.0
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# ...

# %%
nba.fillna(0)
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 586       Jordan Poole  Washington Wizards        G    6-4   194.0
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# ...

# %%
nba['Salary'] #this is a view of original dataframe 

nba['Salary'].fillna(0) #when we call fillna method, this returns a copy
# Out:
# 0       4556983.0
# 1      18700000.0
# 2       4094244.0
# 3      20616000.0
# 4       2581522.0
#           ...
# 586    27955357.0
# 587     1719864.0
# 588    10250000.0
# 589           0.0
# 590     8195122.0
# Name: Salary, Length: 591, dtype: float64

# %%
nba['Salary'] = nba['Salary'].fillna(0)

# %%
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 586       Jordan Poole  Washington Wizards        G    6-4   194.0
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# ...

# %%
nba['College'] = nba['College'].fillna('unknown')

# %%
nba.head(17)
# Out:
#                  Name           Team Position Height  Weight  \
# 0          Saddiq Bey  Atlanta Hawks        F    6-7   215.0
# 1   Bogdan Bogdanovic  Atlanta Hawks        G    6-5   225.0
# 2         Kobe Bufkin  Atlanta Hawks        G    6-5   195.0
# 3        Clint Capela  Atlanta Hawks        C   6-10   256.0
# 4      Bruno Fernando  Atlanta Hawks      F-C   6-10   240.0
# 5       Trent Forrest  Atlanta Hawks        G    6-4   210.0
# 6          AJ Griffin  Atlanta Hawks        F    6-6   220.0
# 7      Mouhamed Gueye  Atlanta Hawks        F   6-11   210.0
# 8     De'Andre Hunter  Atlanta Hawks      F-G    6-8   221.0
# 9       Jalen Johnson  Atlanta Hawks        F    6-8   219.0
# 10         Seth Lundy  Atlanta Hawks        G    6-6   220.0
# 11   Garrison Mathews  Atlanta Hawks        G    6-6   215.0
# 12    Wesley Matthews  Atlanta Hawks        G    6-5   220.0
# 13        Patty Mills  Atlanta Hawks        G    6-0   180.0
# ...

# %% [markdown]
# ## The astype Method I
# - The `astype` method converts a **Series's** values to a specified type.
# - Pass in the specified type as either a string or the core Python data type.
# - Pandas cannot convert `NaN` values to numeric types, so we need to eliminate/replace them before we perform the conversion.
# - The `dtypes` attribute returns a **Series** with the **DataFrame's** columns and their types.

# %%
nba = pd.read_csv('nba.csv').dropna(how='all')
nba['Salary'] = nba['Salary'].fillna(0)
nba['Weight'] = nba['Weight'].fillna(0) #filling missing values with 0
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 586       Jordan Poole  Washington Wizards        G    6-4   194.0
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# ...

# %%
nba.dtypes
# Out:
# Name         object
# Team         object
# Position     object
# Height       object
# Weight      float64
# College      object
# Salary      float64
# dtype: object

# %%
nba['Salary'].astype(int)
nba['Salary'] = nba['Salary'].astype(int)  #now the salary column will have int values, dataframe is also affected
#now targeting weight column
nba['Weight'] = nba['Weight'].astype(int)

#after this, if we call dtype and check datatype of each column, it will show int for changes made above

# %%
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7     215
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5     225
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5     195
# 3         Clint Capela       Atlanta Hawks        C   6-10     256
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10     240
# ..                 ...                 ...      ...    ...     ...
# 586       Jordan Poole  Washington Wizards        G    6-4     194
# 587       Ryan Rollins  Washington Wizards        G    6-3     180
# 588      Landry Shamet  Washington Wizards        G    6-4     190
# 589   Tristan Vukcevic  Washington Wizards        F   6-10     220
# 590       Delon Wright  Washington Wizards        G    6-5     185
#
#            College    Salary
# 0        Villanova   4556983
# 1       Fenerbahce  18700000
# 2         Michigan   4094244
# 3      Elan Chalon  20616000
# ...

# %%
nba.dtypes
# Out:
# Name        object
# Team        object
# Position    object
# Height      object
# Weight       int32
# College     object
# Salary       int32
# dtype: object

# %% [markdown]
# ## The astype Method II
# - The `category` type is ideal for columns with a limited number of unique values.
# - The `nunique` method will return a **Series** with the number of unique values in each column.
# - With categories, pandas does not create a separate value in memory for each "cell". Rather, the cells point to a single copy for each unique value.

# %%
nba = pd.read_csv('nba.csv').dropna(how='all')
nba.tail()
# Out:
#                  Name                Team Position Height  Weight  \
# 586      Jordan Poole  Washington Wizards        G    6-4   194.0
# 587      Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588     Landry Shamet  Washington Wizards        G    6-4   190.0
# 589  Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590      Delon Wright  Washington Wizards        G    6-5   185.0
#
#            College      Salary
# 586       Michigan  27955357.0
# 587         Toledo   1719864.0
# 588  Wichita State  10250000.0
# 589    Real Madrid         NaN
# 590           Utah   8195122.0

# %%
nba['Team'].nunique()  #retunns how many unique values there are
# Out:
# 30

# %%
nba.nunique()  #this way it will tell how many unique value are there in each column
# Out:
# Name        591
# Team         30
# Position      7
# Height       20
# Weight       93
# College     182
# Salary      298
# dtype: int64

# %%
nba['Position'] =nba['Position'].astype('category')  #category is best to use when there is limited number or small number of unique values

# %%
nba['Team'] = nba['Team'].astype('category')

# %%
#now if we check info , and datatype it will show category
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 591 entries, 0 to 590
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      591 non-null    object
#  1   Team      591 non-null    category
#  2   Position  584 non-null    category
#  3   Height    585 non-null    object
#  4   Weight    584 non-null    float64
#  5   College   578 non-null    object
#  6   Salary    488 non-null    float64
# dtypes: category(2), float64(2), object(3)
# memory usage: 30.5+ KB

# %% [markdown]
# ## Sort a DataFrame with the sort_values Method I
# - The `sort_values` method sorts a **DataFrame** by the values in one or more columns. The default sort is an ascending one (alphabetical for strings).
# - The first parameter (`by`) expects the column(s) to sort by.
# - If sorting by a single column, pass a string with its name.
# - The `ascending` parameter customizes the sort order.
# - The `na_position` parameter customizes where pandas places `NaN` values.

# %%
nba = pd.read_csv('nba.csv')
nba.tail()
# Out:
#                  Name                Team Position Height  Weight  \
# 587      Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588     Landry Shamet  Washington Wizards        G    6-4   190.0
# 589  Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590      Delon Wright  Washington Wizards        G    6-5   185.0
# 591               NaN                 NaN      NaN    NaN     NaN
#
#            College      Salary
# 587         Toledo   1719864.0
# 588  Wichita State  10250000.0
# 589    Real Madrid         NaN
# 590           Utah   8195122.0
# 591            NaN         NaN

# %%
nba['Name'].sort_values()  #this way, we get a series then sort values
# Out:
# 122        A.J. Lawson
# 324           AJ Green
# 6           AJ Griffin
# 141       Aaron Gordon
# 198      Aaron Holiday
#             ...
# 83         Zach LaVine
# 149         Zeke Nnaji
# 291    Ziaire Williams
# 370    Zion Williamson
# 591                NaN
# Name: Name, Length: 592, dtype: object

# %%
#if want to sort the column in the data frame itself then
nba.sort_values('Name')   #the column values are sorted , by default it sorts in ascending order
# Out:
#                 Name                  Team Position Height  Weight  \
# 122      A.J. Lawson      Dallas Mavericks        G    6-6   179.0
# 324         AJ Green       Milwaukee Bucks        G    6-5   190.0
# 6         AJ Griffin         Atlanta Hawks        F    6-6   220.0
# 141     Aaron Gordon        Denver Nuggets        F    6-8   235.0
# 198    Aaron Holiday       Houston Rockets        G    6-0   185.0
# ..               ...                   ...      ...    ...     ...
# 83       Zach LaVine         Chicago Bulls        G    6-5   200.0
# 149       Zeke Nnaji        Denver Nuggets      F-C    6-9   240.0
# 291  Ziaire Williams     Memphis Grizzlies        F    6-9   185.0
# 370  Zion Williamson  New Orleans Pelicans        F    6-6   284.0
# 591              NaN                   NaN      NaN    NaN     NaN
#
#             College      Salary
# 122  South Carolina         NaN
# 324   Northern Iowa   1901769.0
# 6              Duke   3712920.0
# ...

# %%
nba.sort_values('Name',ascending=False)  #this way it sorts the column in descending order
# Out:
#                 Name                  Team Position Height  Weight  \
# 370  Zion Williamson  New Orleans Pelicans        F    6-6   284.0
# 291  Ziaire Williams     Memphis Grizzlies        F    6-9   185.0
# 149       Zeke Nnaji        Denver Nuggets      F-C    6-9   240.0
# 83       Zach LaVine         Chicago Bulls        G    6-5   200.0
# 515     Zach Collins     San Antonio Spurs      F-C   6-11   250.0
# ..               ...                   ...      ...    ...     ...
# 141     Aaron Gordon        Denver Nuggets        F    6-8   235.0
# 6         AJ Griffin         Atlanta Hawks        F    6-6   220.0
# 324         AJ Green       Milwaukee Bucks        G    6-5   190.0
# 122      A.J. Lawson      Dallas Mavericks        G    6-6   179.0
# 591              NaN                   NaN      NaN    NaN     NaN
#
#             College      Salary
# 370            Duke  34005250.0
# 291        Stanford   4810200.0
# 149         Arizona   4306281.0
# ...

# %%
nba.sort_values('Salary')  #in salary column there are missing values, by default, it will come at bottom
#but the values will be sorted in ascending or reverse order

nba.sort_values('Salary',ascending=False) #here values are sorted in descending order
# Out:
#                  Name                   Team Position Height  Weight  \
# 175     Stephen Curry  Golden State Warriors        G    6-2   185.0
# 461      Kevin Durant           Phoenix Suns        F   6-10   240.0
# 436       Joel Embiid     Philadelphia 76ers      C-F    7-0   280.0
# 145      Nikola Jokic         Denver Nuggets        C   6-11   284.0
# 261      LeBron James     Los Angeles Lakers        F    6-9   250.0
# ..                ...                    ...      ...    ...     ...
# 547    Gary Trent Jr.        Toronto Raptors      G-F    6-5   209.0
# 578        Taj Gibson     Washington Wizards        F    6-9   232.0
# 584     Kendrick Nunn     Washington Wizards        G    6-3   190.0
# 589  Tristan Vukcevic     Washington Wizards        F   6-10   220.0
# 591               NaN                    NaN      NaN    NaN     NaN
#
#                           College      Salary
# 175                      Davidson  51915615.0
# ...

# %%
nba.sort_values('Salary',na_position='last')  #this parameter indicates, where the NaN missing values will be placed, first or last
nba.sort_values('Salary',na_position= 'first')
# Out:
#                     Name                   Team Position Height  Weight  \
# 23         Blake Griffin         Boston Celtics        F    6-9   250.0
# 26     Mfiondu Kabengele         Boston Celtics        C   6-10   250.0
# 28        Svi Mykhailiuk         Boston Celtics      G-F    6-7   205.0
# 35   Robert Williams III         Boston Celtics      C-F    6-9   237.0
# 39           Nic Claxton          Brooklyn Nets        C   6-11   215.0
# ..                   ...                    ...      ...    ...     ...
# 261         LeBron James     Los Angeles Lakers        F    6-9   250.0
# 145         Nikola Jokic         Denver Nuggets        C   6-11   284.0
# 436          Joel Embiid     Philadelphia 76ers      C-F    7-0   280.0
# 461         Kevin Durant           Phoenix Suns        F   6-10   240.0
# 175        Stephen Curry  Golden State Warriors        G    6-2   185.0
#
#                           College      Salary
# 23                       Oklahoma         NaN
# ...

# %%
#here we are sorting , salary column, values will be descending order, but missing values will be placed first
nba.sort_values('Salary',na_position= 'first' ,ascending=False)
# Out:
#                     Name                  Team Position Height  Weight  \
# 23         Blake Griffin        Boston Celtics        F    6-9   250.0
# 26     Mfiondu Kabengele        Boston Celtics        C   6-10   250.0
# 28        Svi Mykhailiuk        Boston Celtics      G-F    6-7   205.0
# 35   Robert Williams III        Boston Celtics      C-F    6-9   237.0
# 39           Nic Claxton         Brooklyn Nets        C   6-11   215.0
# ..                   ...                   ...      ...    ...     ...
# 336    Lindell Wigginton       Milwaukee Bucks        G    6-1   189.0
# 143             Jay Huff        Denver Nuggets        C    7-1   240.0
# 244        Jordan Miller  Los Angeles Clippers        G    6-7   194.0
# 147          Braxton Key        Denver Nuggets        F    6-8   225.0
# 5          Trent Forrest         Atlanta Hawks        G    6-4   210.0
#
#            College    Salary
# 23        Oklahoma       NaN
# 26   Florida State       NaN
# ...

# %% [markdown]
# ## Sort a DataFrame with the sort_values Method II
# - To sort by multiple columns, pass the `by` parameter a list of column names. Pandas will sort in the specified column order (first to last).
# - Pass the `ascending` parameter a Boolean to sort all columns in a consistent order (all ascending or all descending).
# - Pass `ascending` a list to customize the sort order *per* column. The `ascending` list length must match the `by` list.

# %%
nba = pd.read_csv('nba.csv')
nba.tail()
# Out:
#                  Name                Team Position Height  Weight  \
# 587      Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588     Landry Shamet  Washington Wizards        G    6-4   190.0
# 589  Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590      Delon Wright  Washington Wizards        G    6-5   185.0
# 591               NaN                 NaN      NaN    NaN     NaN
#
#            College      Salary
# 587         Toledo   1719864.0
# 588  Wichita State  10250000.0
# 589    Real Madrid         NaN
# 590           Utah   8195122.0
# 591            NaN         NaN

# %%
nba.sort_values(['Team','Name'])
nba.sort_values(by=['Team','Name'], ascending=True) 
nba.sort_values(by=['Team','Name'], ascending=False)
# Out:
#                   Name                Team Position Height  Weight  \
# 573       Xavier Cooks  Washington Wizards        F    6-8   183.0
# 580         Tyus Jones  Washington Wizards        G    6-2   196.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 578         Taj Gibson  Washington Wizards        F    6-9   232.0
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# ..                 ...                 ...      ...    ...     ...
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 6           AJ Griffin       Atlanta Hawks        F    6-6   220.0
# 591                NaN                 NaN      NaN    NaN     NaN
#
#                  College      Salary
# 573             Winthrop   1719864.0
# 580                 Duke  14000000.0
# 589          Real Madrid         NaN
# ...

# %%
#to sort one column in ascending order, and other in descending order ,we can give True and false , which will be respectively aplied to column names
nba.sort_values(by=['Team','Name'], ascending=[True,False])  #here True is given to Team ,False is given to Name respectively
# Out:
#                 Name                Team Position Height  Weight  \
# 12   Wesley Matthews       Atlanta Hawks        G    6-5   220.0
# 5      Trent Forrest       Atlanta Hawks        G    6-4   210.0
# 17        Trae Young       Atlanta Hawks        G    6-1   164.0
# 10        Seth Lundy       Atlanta Hawks        G    6-6   220.0
# 0         Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# ..               ...                 ...      ...    ...     ...
# 576   Daniel Gafford  Washington Wizards      F-C   6-10   234.0
# 581    Corey Kispert  Washington Wizards        F    6-6   224.0
# 574  Bilal Coulibaly  Washington Wizards        G    6-6   195.0
# 579     Anthony Gill  Washington Wizards        F    6-8   230.0
# 591              NaN                 NaN      NaN    NaN     NaN
#
#               College      Salary
# 12          Marquette   3196448.0
# 5       Florida State    508891.0
# 17           Oklahoma  40064220.0
# 10         Penn State    559782.0
# ...

# %%
nba.sort_values(['Position','Salary'], ascending=[True, False])
nba.sort_values(['Position', 'Salary'], ascending = False)
nba.sort_values(['Position', 'Salary'], ascending = [False,True])
# Out:
#                 Name                    Team Position Height  Weight  \
# 392    Dylan Windler         New York Knicks      G-F    6-7   196.0
# 202   Joshua Obiesie         Houston Rockets      G-F    6-6   195.0
# 484     Rayan Rupert  Portland Trail Blazers      G-F    6-6   185.0
# 130     Joe Wieskamp        Dallas Mavericks      G-F    6-6   205.0
# 197      Nate Hinton         Houston Rockets      G-F    6-5   210.0
# ..               ...                     ...      ...    ...     ...
# 138  Armaan Franklin          Denver Nuggets      NaN    NaN     NaN
# 299    Caleb Daniels              Miami Heat      NaN    NaN     NaN
# 541     Kevin Obanor         Toronto Raptors      NaN    6-8   235.0
# 564     Nick Ongenda               Utah Jazz      NaN    NaN     NaN
# 591              NaN                     NaN      NaN    NaN     NaN
#
#                   College     Salary
# 392               Belmont   559782.0
# 202                   NaN  1119563.0
# ...

# %% [markdown]
# ## Sort a DataFrame by its Index
# - The `sort_index` method sorts the **DataFrame** by its index positions/labels.

# %%
nba = pd.read_csv('nba.csv')
nba = nba.sort_values(['Team' , 'Name'])

# %%
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 6           AJ Griffin       Atlanta Hawks        F    6-6   220.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 8      De'Andre Hunter       Atlanta Hawks      F-G    6-8   221.0
# ..                 ...                 ...      ...    ...     ...
# 578         Taj Gibson  Washington Wizards        F    6-9   232.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 580         Tyus Jones  Washington Wizards        G    6-2   196.0
# 573       Xavier Cooks  Washington Wizards        F    6-8   183.0
# 591                NaN                 NaN      NaN    NaN     NaN
#
#                  College      Salary
# 6                   Duke   3712920.0
# 1             Fenerbahce  18700000.0
# 4               Maryland   2581522.0
# ...

# %%
nba.sort_index()
nba.sort_index(ascending= True)

#in descending order
nba.sort_index(ascending = False)  #this returns a copy , if want to keep it then reassign it to nba
# Out:
#                   Name                Team Position Height  Weight  \
# 591                NaN                 NaN      NaN    NaN     NaN
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# ..                 ...                 ...      ...    ...     ...
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
#
#            College      Salary
# 591            NaN         NaN
# 590           Utah   8195122.0
# 589    Real Madrid         NaN
# 588  Wichita State  10250000.0
# ...

# %%
nba = nba.sort_index(ascending=False) #reassigning to nba to keep it 
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 591                NaN                 NaN      NaN    NaN     NaN
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# ..                 ...                 ...      ...    ...     ...
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
#
#            College      Salary
# 591            NaN         NaN
# 590           Utah   8195122.0
# 589    Real Madrid         NaN
# 588  Wichita State  10250000.0
# ...

# %% [markdown]
# ## Rank Values with the rank Method
# - The `rank` method assigns a numeric ranking to each **Series** value.
# - Pandas will assign the same rank to equal values and create a "gap" in the dataset for the ranks.

# %%
nba = pd.read_csv('nba.csv').dropna(how='all')
nba['Salary'] = nba['Salary'].fillna(0).astype('int')#to salary colufilling missing values with 0, then passing as astype to replace floating type with integer type
nba                                                   #assigning this changes to salary column
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 586       Jordan Poole  Washington Wizards        G    6-4   194.0
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
#
#            College    Salary
# 0        Villanova   4556983
# 1       Fenerbahce  18700000
# 2         Michigan   4094244
# 3      Elan Chalon  20616000
# ...

# %%
nba['Salary'].rank() #by defult values of salary column are assigned in ascending order , the highest value has been given the highes rank, lowest value has the lowest rank
# Out:
# 0      361.0
# 1      512.0
# 2      349.0
# 3      523.0
# 4      284.0
#        ...
# 586    544.0
# 587    197.5
# 588    452.0
# 589     52.0
# 590    429.0
# Name: Salary, Length: 591, dtype: float64

# %%
nba['Salary'].rank(ascending=False).astype(int) #now it is reversed, highest salary is given lowest num like 1 , 2 ,3 so on
#assigning it to the existing nba dataset, to a new column 
nba['Salary Rank'] = nba['Salary'].rank(ascending=False).astype(int)

# %%
#now to get the highest salaryt value , we can use sort_values method 

nba.sort_values('Salary Rank') #sorting this column in ascending order will give tbe lowest rank number, which is given to higest salary 

nba.sort_values('Salary', ascending=False).head(10) # we can use this way also , default it will sorted in ascending so have to give false for descending order for 
                                            # highest value to lowest
# Out:
#                       Name                    Team Position Height  Weight  \
# 175          Stephen Curry   Golden State Warriors        G    6-2   185.0
# 461           Kevin Durant            Phoenix Suns        F   6-10   240.0
# 261           LeBron James      Los Angeles Lakers        F    6-9   250.0
# 145           Nikola Jokic          Denver Nuggets        C   6-11   284.0
# 436            Joel Embiid      Philadelphia 76ers      C-F    7-0   280.0
# 456           Bradley Beal            Phoenix Suns        G    6-4   207.0
# 480         Damian Lillard  Portland Trail Blazers        G    6-2   195.0
# 316  Giannis Antetokounmpo         Milwaukee Bucks        F    7-0   243.0
# 241          Kawhi Leonard    Los Angeles Clippers        F    6-7   225.0
# 239            Paul George    Los Angeles Clippers        F    6-8   220.0
#
#                           College    Salary  Salary Rank
# 175                      Davidson  51915615            1
# ...
